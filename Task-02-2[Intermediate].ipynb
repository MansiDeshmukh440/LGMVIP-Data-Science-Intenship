# %% [markdown]
# # LGMVIP
# Data Science Internship task 2-2

# %%
import numpy as np
import matplotlib.pyplot as plt
# !pip install scikit-plot
import scikitplot as skplt
import pandas as pd
import seaborn as sns
# Out:
# WARNING: Ignoring invalid distribution -atplotlib (c:\python3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python3.10\lib\site-packages)
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-plot in c:\python3.10\lib\site-packages (0.3.7)
# Requirement already satisfied: joblib>=0.10 in c:\python3.10\lib\site-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: matplotlib>=1.4.0 in c:\python3.10\lib\site-packages (from scikit-plot) (3.8.2)
# Requirement already satisfied: scipy>=0.9 in c:\python3.10\lib\site-packages (from scikit-plot) (1.9.3)
# Requirement already satisfied: scikit-learn>=0.18 in c:\python3.10\lib\site-packages (from scikit-plot) (1.3.1)
# Requirement already satisfied: numpy<2,>=1.21 in c:\python3.10\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.23.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python3.10\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python3.10\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python3.10\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\python3.10\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python3.10\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python3.10\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\python3.10\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: pillow>=8 in c:\python3.10\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (9.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python3.10\lib\site-packages (from scikit-learn>=0.18->scikit-plot) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\python3.10\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
data = pd.read_csv("Iris.csv")

# %%
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
data.shape
# Out:
# (150, 5)

# %%
data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
data.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.nunique()
# Out:
# SepalLengthCm    35
# SepalWidthCm     23
# PetalLengthCm    43
# PetalWidthCm     22
# Species           3
# dtype: int64

# %%
data.Species.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
data.max()
# Out:
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
data.min()
# Out:
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
# target Class Count
sns.countplot(y=data.Species ,data=data, palette="viridis")
plt.xlabel("Count of each Target class")
plt.ylabel("Target classes")
plt.show()

# %%
data.plot(kind = 'box', subplots=True, layout = (3,2), figsize = (8,12))
# Out:
# SepalLengthCm       Axes(0.125,0.653529;0.352273x0.226471)
# SepalWidthCm     Axes(0.547727,0.653529;0.352273x0.226471)
# PetalLengthCm       Axes(0.125,0.381765;0.352273x0.226471)
# PetalWidthCm     Axes(0.547727,0.381765;0.352273x0.226471)
# dtype: object

# %%
data.hist(figsize=(12,12))
plt.show()

# %%
sns.boxplot(x = 'Species', y = 'PetalLengthCm', data=data)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.boxplot(x = 'Species', y = 'PetalWidthCm', data=data)
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
sns.boxplot(x = 'Species', y = 'SepalLengthCm', data=data)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.boxplot(x = 'Species', y = 'SepalWidthCm', data=data)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
#Sepal Length VS Sepal Width
fig = data[data.Species=='Iris-setosa'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='orange', label='Setosa')
data[data.Species=='Iris-versicolor'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='blue', label='versicolor',ax=fig)
data[data.Species=='Iris-virginica'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='green', label='virginica', ax=fig)
fig.set_xlabel("Sepal Length")
fig.set_ylabel("Sepal Width")
fig.set_title("Sepal Length VS Sepal Width")
plt.show()

# %%
#Petal Length VS Petal Width
fig = data[data.Species=='Iris-setosa'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='orange', label='Setosa')
data[data.Species=='Iris-versicolor'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='blue', label='versicolor',ax=fig)
data[data.Species=='Iris-virginica'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='green', label='virginica', ax=fig)
fig.set_xlabel("Petal Length")
fig.set_ylabel("Petal Width")
fig.set_title(" Petal Length VS Petal Width")
plt.show()

# %%
sns.pairplot(data, hue = 'Species')       #A pairwise relationship in data

# %%
data.corr()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_3128\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
plt.figure(figsize= (10,7))
sns.heatmap(data.corr(), annot=True, cmap = 'cubehelix_r')
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_3128\446583804.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, cmap = 'cubehelix_r')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data['Species'] = le.fit_transform(data['Species'])     #returns encoding labels
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
x = data.drop(columns = ['Species'])

# %%
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y = data['Species']       #target
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Species, dtype: int32

# %%
from sklearn.model_selection import train_test_split
tt = train_test_split
xtrain, xtest, ytrain, ytest = tt(x, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
knn = KNeighborsClassifier()
svc = SVC()
gnb = GaussianNB()
dtc = DecisionTreeClassifier()
rfc = RandomForestClassifier()

# %%
models = [lr, knn, svc, gnb, dtc, rfc]
scores = []

for model in models:
  model.fit(xtrain, ytrain)
  ypred = model.predict(xtest)
  scores.append(accuracy_score(ytest, ypred))
  print("Accuracy of " + type(model).__name__+ ' is', accuracy_score(ytest, ypred))
# Out:
# Accuracy of LogisticRegression is 0.9777777777777777
# Accuracy of KNeighborsClassifier is 0.9777777777777777
# Accuracy of SVC is 0.9777777777777777
# Accuracy of GaussianNB is 1.0
# Accuracy of DecisionTreeClassifier is 0.9777777777777777
# Accuracy of RandomForestClassifier is 0.9777777777777777

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(ytest, ypred)
cm
# Out:
# array([[16,  0,  0],
#        [ 0, 17,  1],
#        [ 0,  0, 11]], dtype=int64)

# %%
sns.heatmap(cm, cmap = 'Reds')
# Out:
# <Axes: >

# %%
from sklearn import tree
tree.plot_tree(dtc)
# Out:
# [Text(0.4, 0.9, 'x[2] <= 2.35\ngini = 0.664\nsamples = 105\nvalue = [34, 32, 39]'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]'),
#  Text(0.5, 0.7, 'x[2] <= 4.95\ngini = 0.495\nsamples = 71\nvalue = [0, 32, 39]'),
#  Text(0.2, 0.5, 'x[3] <= 1.65\ngini = 0.161\nsamples = 34\nvalue = [0, 31, 3]'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 30\nvalue = [0, 30, 0]'),
#  Text(0.3, 0.3, 'x[1] <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5, 'x[3] <= 1.75\ngini = 0.053\nsamples = 37\nvalue = [0, 1, 36]'),
#  Text(0.7, 0.3, 'x[3] <= 1.65\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9, 0.3, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 33]')]

# %%
pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in c:\python3.10\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\python3.10\lib\site-packages (from pydotplus) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\python3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\python3.10\lib\site-packages)
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from six import StringIO
import pydotplus
import matplotlib.image as mpimg
from sklearn import tree
# %matplotlib inline

# %%
Species_tree=DecisionTreeClassifier(criterion="entropy",max_depth=5)

# %%
Species_tree.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
prediction=Species_tree.predict(xtest)

# %%
print(prediction[0:5])
print(ytest[0:5])
# Out:
# [2 1 0 2 0]
# 114    2
# 62     1
# 33     0
# 107    2
# 7      0
# Name: Species, dtype: int32
# C:\Users\Acer\AppData\Local\Temp\ipykernel_3128\1792471458.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   print(ytest[0:5])
